# %%
import pandas as pd

# %%
#Reading the csv file
data=pd.read_csv('/kaggle/input/weather-data/Weather Data.csv')

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
#Show the first 10 rows in the data
data.head(10)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
# 8  1/1/2012 8:00    -1.4              -3.6         85                9
# 9  1/1/2012 9:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %%
#Provides basic information about the dataframe : row ,columns , types (if automatic detected)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
#Find out different weather conditions available 
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
#Q: To find unique instances of weather types
weather=data['Weather'].value_counts()
dataweather=pd.DataFrame(weather)
dataweather = dataweather.reset_index()
dataweather.columns = ['Weather', 'Frequency'] # change column names
dataweather
# Out:
#                                     Weather  Frequency
# 0                              Mainly Clear       2106
# 1                             Mostly Cloudy       2069
# 2                                    Cloudy       1728
# 3                                     Clear       1326
# 4                                      Snow        390
# 5                                      Rain        306
# 6                              Rain Showers        188
# 7                                       Fog        150
# 8                                  Rain,Fog        116
# 9                               Drizzle,Fog         80
# 10                             Snow Showers         60
# 11                                  Drizzle         41
# 12                                 Snow,Fog         37
# 13                        Snow,Blowing Snow         19
# 14                                Rain,Snow         18
# 15               Thunderstorms,Rain Showers         16
# ...

# %%
#Q: Find the number of times when the weather was exactly 'clear'
#data['Weather'].value_counts() it count occurrences of each unique value .
len(data[(data.Weather=='Clear')])
# Out:
# 1326

# %%
#this is the another way to find the number of times when the weather was exactly 'clear'
data[data['Weather'] == 'Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
#Q: To rename column named 'Weather' to Weather Condition'
data.rename(columns = {'Weather' : 'Weather_Condition'}, inplace=False)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
#Find all the unique wind speed value 
data['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
#find the number of times when the wind speed was exactly 7km/h
len(data[(data['Wind Speed_km/h']==7)])
# Out:
# 677

# %%
#another way 
data['Wind Speed_km/h'].value_counts()[7]
# Out:
# 677

# %%
#Q: To find the mean temperature, wind speed and visibility
print(data['Temp_C'].mean())
print(data['Wind Speed_km/h'].mean())
print(data['Visibility_km'].mean())
# Out:
# 8.798144353369764
# 14.94546903460838
# 27.664446721311478

# %%
#Q: To find the days on which wind speed was less than or equal to 30 km/hr and temperature was greater than 0 C
windspeed=data[(data['Wind Speed_km/h'] <=30) & (data['Temp_C']>0)]
print(windspeed['Date/Time'])
print(windspeed.shape)
# Out:
# 13        1/1/2012 13:00
# 14        1/1/2012 14:00
# 15        1/1/2012 15:00
# 16        1/1/2012 16:00
# 17        1/1/2012 17:00
#               ...
# 8545     12/22/2012 1:00
# 8546     12/22/2012 2:00
# 8547     12/22/2012 3:00
# 8779    12/31/2012 19:00
# 8780    12/31/2012 20:00
# Name: Date/Time, Length: 6302, dtype: object
# (6302, 8)

# %%
#find out all the value of wind speed
data['Wind Speed_km/h'].value_counts()
# Out:
# Wind Speed_km/h
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 43     13
# 48     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 83      1
# 70      1
# 63      1
# 54      1
# Name: count, dtype: int64

# %%
#Q: To find the date and temperatures for all instances when snow was recorded
snow=data[data['Weather'] == 'Snow']
snow.loc[:, ['Date/Time', 'Temp_C']]
# Out:
#              Date/Time  Temp_C
# 55       1/3/2012 7:00   -14.0
# 84      1/4/2012 12:00   -13.7
# 86      1/4/2012 14:00   -11.3
# 87      1/4/2012 15:00   -10.2
# 88      1/4/2012 16:00    -9.4
# ...                ...     ...
# 8779  12/31/2012 19:00     0.1
# 8780  12/31/2012 20:00     0.2
# 8781  12/31/2012 21:00    -0.5
# 8782  12/31/2012 22:00    -0.2
# 8783  12/31/2012 23:00     0.0
#
# [390 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#Q: To display a graph of variation of temperature with respect to time
graph=data[['Temp_C', 'Date/Time']]
graph.plot(x='Date/Time', y='Temp_C',figsize=(10,7) )
# Out:
# <Axes: xlabel='Date/Time'>

# %%
#Q: To display a pie chart of percentages of weather conditions

keep=dataweather[dataweather['Frequency']>20]
print(keep)
keep.plot.pie(y='Frequency',autopct='%1.1f%%', shadow=False, figsize=(12,9))
plt.title("Weather")
plt.show()
# Out:
#           Weather  Frequency
# 0    Mainly Clear       2106
# 1   Mostly Cloudy       2069
# 2          Cloudy       1728
# 3           Clear       1326
# 4            Snow        390
# 5            Rain        306
# 6    Rain Showers        188
# 7             Fog        150
# 8        Rain,Fog        116
# 9     Drizzle,Fog         80
# 10   Snow Showers         60
# 11        Drizzle         41
# 12       Snow,Fog         37
